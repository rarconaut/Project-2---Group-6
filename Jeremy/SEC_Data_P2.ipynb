# %% [markdown]
# ### Import SEC Data File Created in Project2_SEC_Filings Notebook

# %%
import pandas as pd
import os
import csv

# %%
sec_path = 'sec_df_export.csv'
sec_df = pd.read_csv(sec_path)
sec_df.head()
sec_df = sec_df[['cik', 'name', 'countryba', 'stprba', 'cityba', 'zipba', 'form', 'latitude', 'longitude']]
sec_df.dropna(axis=0, how="any", subset=['stprba'], inplace=True)
sec_df.drop_duplicates(inplace=True)
sec_df.sort_values(by="cik", ascending=True, inplace=True)
sec_df.head()
# Out:
#        cik                            name countryba stprba       cityba  \
# 1734  1750                        AAR CORP        US     IL    WOOD DALE
# 1735  1800             ABBOTT LABORATORIES        US     IL  ABBOTT PARK
# 2335  1961                      WORLDS INC        US     MA    BROOKLINE
# 1163  2098                ACME UNITED CORP        US     CT    FAIRFIELD
# 4226  2178  ADAMS RESOURCES & ENERGY, INC.        US     TX      HOUSTON
#
#            zipba  form   latitude  longitude
# 1734       60191  10-K   41.98568  -87.97991
# 1735  60064-3500  10-K    Missing    Missing
# 2335        2445  10-K  42.336193   -71.1295
# 1163        6824  10-K  41.147858  -73.25259
# 4226       77027  10-K   29.75137  -95.45202

# %%
sec_df.shape
# Out:
# (5044, 9)

# %%
sec_json = 'https://www.sec.gov/files/company_tickers.json'

# %%
stock_tickers = pd.read_json(sec_json).transpose()

# %%
stock_tickers.set_index('cik_str', inplace=True)
stock_tickers.head()
# Out:
#         ticker           title
# cik_str
# 320193    AAPL      Apple Inc.
# 789019    MSFT  MICROSOFT CORP
# 1018724   AMZN  AMAZON COM INC
# 1652044   GOOG   Alphabet Inc.
# 1326801     FB    Facebook Inc

# %%
stock_tickers.drop_duplicates(inplace=True)
stock_tickers.shape
# Out:
# (10862, 2)

# %%
sec_df = sec_df.merge(stock_tickers, how="left", left_on="cik", right_index=True)
sec_df.sort_values(by='cik', ascending=True, inplace=True)
sec_df.drop(columns=['name', 'form'], inplace=True)
sec_df.head()
# Out:
#        cik countryba stprba       cityba       zipba   latitude  longitude  \
# 1734  1750        US     IL    WOOD DALE       60191   41.98568  -87.97991
# 1735  1800        US     IL  ABBOTT PARK  60064-3500    Missing    Missing
# 2335  1961        US     MA    BROOKLINE        2445  42.336193   -71.1295
# 1163  2098        US     CT    FAIRFIELD        6824  41.147858  -73.25259
# 4226  2178        US     TX      HOUSTON       77027   29.75137  -95.45202
#
#      ticker                           title
# 1734    AIR                        AAR CORP
# 1735    ABT             ABBOTT LABORATORIES
# 2335   WDDD                      WORLDS INC
# 1163    ACU                ACME UNITED CORP
# 4226     AE  ADAMS RESOURCES & ENERGY, INC.

# %%
sec_df = sec_df[['cik', 'ticker', 'title', 'countryba', 'stprba', 'cityba', 'zipba', 'latitude', 'longitude']]

sec_df.head()
# Out:
#        cik ticker                           title countryba stprba  \
# 1734  1750    AIR                        AAR CORP        US     IL
# 1735  1800    ABT             ABBOTT LABORATORIES        US     IL
# 2335  1961   WDDD                      WORLDS INC        US     MA
# 1163  2098    ACU                ACME UNITED CORP        US     CT
# 4226  2178     AE  ADAMS RESOURCES & ENERGY, INC.        US     TX
#
#            cityba       zipba   latitude  longitude
# 1734    WOOD DALE       60191   41.98568  -87.97991
# 1735  ABBOTT PARK  60064-3500    Missing    Missing
# 2335    BROOKLINE        2445  42.336193   -71.1295
# 1163    FAIRFIELD        6824  41.147858  -73.25259
# 4226      HOUSTON       77027   29.75137  -95.45202

# %%
sec_df.rename(columns={'cik':'cik', 'countryba':'country', 'stprba':'state', 'cityba':'city', 'zipba':'zipcode', \
                       'latitude':'lat', 'longitude':'lon', 'ticker':'ticker', 'title':'name'}, inplace=True)

sec_df.head()
# Out:
#        cik ticker                            name country state         city  \
# 1734  1750    AIR                        AAR CORP      US    IL    WOOD DALE
# 1735  1800    ABT             ABBOTT LABORATORIES      US    IL  ABBOTT PARK
# 2335  1961   WDDD                      WORLDS INC      US    MA    BROOKLINE
# 1163  2098    ACU                ACME UNITED CORP      US    CT    FAIRFIELD
# 4226  2178     AE  ADAMS RESOURCES & ENERGY, INC.      US    TX      HOUSTON
#
#          zipcode        lat        lon
# 1734       60191   41.98568  -87.97991
# 1735  60064-3500    Missing    Missing
# 2335        2445  42.336193   -71.1295
# 1163        6824  41.147858  -73.25259
# 4226       77027   29.75137  -95.45202

# %%
sec_df.shape
# Out:
# (6055, 9)

# %%
mask1 = sec_df['lat'] == "Missing"
missing_df = sec_df[mask1]
missing_df.set_index('ticker', inplace=True)
missing_df.head()
# Out:
#          cik                               name country state         city  \
# ticker
# ABT     1800                ABBOTT LABORATORIES      US    IL  ABBOTT PARK
# APD     2969  AIR PRODUCTS & CHEMICALS INC /DE/      US    PA    ALLENTOWN
# ALX     3499                     ALEXANDERS INC      US    NJ      PARAMUS
# ALCO    3545                        ALICO, INC.      US    FL   FT. MYERS,
# AEPPL   4904     AMERICAN ELECTRIC POWER CO INC      US    OH     COLUMBUS
#
#            zipcode      lat      lon
# ticker
# ABT     60064-3500  Missing  Missing
# APD     18195-1501  Missing  Missing
# ALX           7652  Missing  Missing
# ALCO         33913  Missing  Missing
# AEPPL        43215  Missing  Missing

# %%
missing_df.shape
# Out:
# (1406, 8)

# %%
# missing_df.to_csv('missing_df.csv', index=False)

# %%
missing_coordinates_path = 'missing_df2.csv'
missing_coordinates_df = pd.read_csv(missing_coordinates_path)
missing_coordinates_df = missing_coordinates_df[['ticker', 'lat', 'lon']]
missing_coordinates_df.set_index('ticker', inplace=True)

missing_coordinates_df.rename(columns={'lat':'latitude', 'lon':'longitude'}, inplace=True)
missing_coordinates_df
# Out:
#        latitude longitude
# ticker
# ABT     Missing   Missing
# APD     40.6028  -75.4698
# ALX     40.9473  -74.0710
# ALCO    26.6167  -81.8333
# AEPPL   39.9833  -82.9833
# ...         ...       ...
# GNRSW   40.8202  -73.4680
# GNRS    40.8202  -73.4680
# GNRSU   40.8202  -73.4680
# OVV     Missing   Missing
# MSGE    40.7130  -74.0072
#
# [1406 rows x 2 columns]

# %%
missing_coordinates_df.shape
# Out:
# (1406, 2)

# %%
updated_coord_df = pd.concat([missing_df, missing_coordinates_df], axis=1)
updated_coord_df.head()
updated_coord_df.drop(columns = ['lat', 'lon'], inplace=True)
updated_coord_df.rename(columns={'latitude':'lat', 'longitude':'lon'}, inplace=True)
updated_coord_df
# Out:
#             cik                                       name country state  \
# ticker
# ABT        1800                        ABBOTT LABORATORIES      US    IL
# APD        2969          AIR PRODUCTS & CHEMICALS INC /DE/      US    PA
# ALX        3499                             ALEXANDERS INC      US    NJ
# ALCO       3545                                ALICO, INC.      US    FL
# AEPPL      4904             AMERICAN ELECTRIC POWER CO INC      US    OH
# ...         ...                                        ...     ...   ...
# GNRSW   1790665                Greenrose Acquisition Corp.      US    NY
# GNRS    1790665                Greenrose Acquisition Corp.      US    NY
# GNRSU   1790665                Greenrose Acquisition Corp.      US    NY
# OVV     1792580                               Ovintiv Inc.      US    CO
# MSGE    1795250  Madison Square Garden Entertainment Corp.      US    NY
#
#                city     zipcode      lat       lon
# ticker
# ABT     ABBOTT PARK  60064-3500  Missing   Missing
# APD       ALLENTOWN  18195-1501  40.6028  -75.4698
# ALX         PARAMUS        7652  40.9473  -74.0710
# ALCO     FT. MYERS,       33913  26.6167  -81.8333
# AEPPL      COLUMBUS       43215  39.9833  -82.9833
# ...             ...         ...      ...       ...
# GNRSW      WOODBURY       11797  40.8202  -73.4680
# GNRS       WOODBURY       11797  40.8202  -73.4680
# GNRSU      WOODBURY       11797  40.8202  -73.4680
# OVV          DENVER       80202  Missing   Missing
# MSGE       NEW YORK       10121  40.7130  -74.0072
#
# [1406 rows x 8 columns]

# %%
updated_coord_df.shape
# Out:
# (1406, 8)

# %%
map1 = sec_df['lat'] != "Missing"
sec_df = sec_df[map1]
sec_df.set_index('ticker', inplace = True)
sec_df
# Out:
#             cik                            name country state            city  \
# ticker
# AIR        1750                        AAR CORP      US    IL       WOOD DALE
# WDDD       1961                      WORLDS INC      US    MA       BROOKLINE
# ACU        2098                ACME UNITED CORP      US    CT       FAIRFIELD
# AE         2178  ADAMS RESOURCES & ENERGY, INC.      US    TX         HOUSTON
# BKTI       2186            BK Technologies Corp      US    FL  WEST MELBOURNE
# ...         ...                             ...     ...   ...             ...
# VTRS    1792044                     Viatris Inc      US    NY        NEW YORK
# SLQT    1794783               SelectQuote, Inc.      US    KS   OVERLAND PARK
# LSACU   1796129       LifeSci Acquisition Corp.      US    NY        NEW YORK
# LSAC    1796129       LifeSci Acquisition Corp.      US    NY        NEW YORK
# HPTY    1797956           Hemp Technology, Inc.      US    CA     SIGNAL HILL
#
#        zipcode        lat        lon
# ticker
# AIR      60191   41.98568  -87.97991
# WDDD      2445  42.336193   -71.1295
# ACU       6824  41.147858  -73.25259
# AE       77027   29.75137  -95.45202
# BKTI     32904  28.096567   -80.6853
# ...        ...        ...        ...
# VTRS     10017   40.75042  -73.97361
# SLQT     66211  38.917656  -94.66206
# LSACU    10019   40.76501  -73.98288
# LSAC     10019   40.76501  -73.98288
# HPTY     90755   33.80996  -118.1687
#
# [4649 rows x 8 columns]

# %%
complete_sec_df = pd.concat([sec_df, updated_coord_df], join="inner")
complete_sec_df.reset_index(inplace=True)
complete_sec_df.head()
# Out:
#   ticker   cik                            name country state            city  \
# 0    AIR  1750                        AAR CORP      US    IL       WOOD DALE
# 1   WDDD  1961                      WORLDS INC      US    MA       BROOKLINE
# 2    ACU  2098                ACME UNITED CORP      US    CT       FAIRFIELD
# 3     AE  2178  ADAMS RESOURCES & ENERGY, INC.      US    TX         HOUSTON
# 4   BKTI  2186            BK Technologies Corp      US    FL  WEST MELBOURNE
#
#   zipcode        lat        lon
# 0   60191   41.98568  -87.97991
# 1    2445  42.336193   -71.1295
# 2    6824  41.147858  -73.25259
# 3   77027   29.75137  -95.45202
# 4   32904  28.096567   -80.6853

# %%
complete_sec_df.shape
# Out:
# (6055, 9)

# %%
mask1 = complete_sec_df['lat'] != "Missing"
complete_sec_df = complete_sec_df[mask1]
complete_sec_df.dropna(axis=0, how="any", inplace=True)
complete_sec_df
# Out:
#      ticker      cik                                       name country state  \
# 0       AIR     1750                                   AAR CORP      US    IL
# 1      WDDD     1961                                 WORLDS INC      US    MA
# 2       ACU     2098                           ACME UNITED CORP      US    CT
# 3        AE     2178             ADAMS RESOURCES & ENERGY, INC.      US    TX
# 4      BKTI     2186                       BK Technologies Corp      US    FL
# ...     ...      ...                                        ...     ...   ...
# 6049  WBQNL  1785494               Woodbridge Liquidation Trust      US    FL
# 6050  GNRSW  1790665                Greenrose Acquisition Corp.      US    NY
# 6051   GNRS  1790665                Greenrose Acquisition Corp.      US    NY
# 6052  GNRSU  1790665                Greenrose Acquisition Corp.      US    NY
# 6054   MSGE  1795250  Madison Square Garden Entertainment Corp.      US    NY
#
#                  city zipcode        lat        lon
# 0           WOOD DALE   60191   41.98568  -87.97991
# 1           BROOKLINE    2445  42.336193   -71.1295
# 2           FAIRFIELD    6824  41.147858  -73.25259
# 3             HOUSTON   77027   29.75137  -95.45202
# 4      WEST MELBOURNE   32904  28.096567   -80.6853
# ...               ...     ...        ...        ...
# 6049  FORT LAUDERDALE   33301    26.1242   -80.1436
# 6050         WOODBURY   11797    40.8202   -73.4680
# 6051         WOODBURY   11797    40.8202   -73.4680
# 6052         WOODBURY   11797    40.8202   -73.4680
# 6054         NEW YORK   10121    40.7130   -74.0072
#
# [5602 rows x 9 columns]

# %%
complete_sec_df['lat'] = pd.to_numeric(complete_sec_df['lat'])
complete_sec_df['lon'] = pd.to_numeric(complete_sec_df['lon'])
complete_sec_df['cik'] = complete_sec_df['cik'].astype('str')

# %%
complete_sec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5602 entries, 0 to 6054
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ticker   5602 non-null   object
#  1   cik      5602 non-null   object
#  2   name     5602 non-null   object
#  3   country  5602 non-null   object
#  4   state    5602 non-null   object
#  5   city     5602 non-null   object
#  6   zipcode  5602 non-null   object
#  7   lat      5602 non-null   float64
#  8   lon      5602 non-null   float64
# dtypes: float64(2), object(7)
# memory usage: 437.7+ KB

# %%
complete_sec_df.to_csv('clean_sec_companies_with_tickers_coord.csv', index=False)
